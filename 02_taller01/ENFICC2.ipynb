# %% [markdown]
# importar librerias a usar

# %%
import os
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# llama carpeta acutal de este cuaderno

# %%
pwd
# Out:
# '/home/nbuser/library/02_taller01'

# %% [markdown]
# funcion que llama la ciudad y la fuente

# %%
def ghi(serie_horaria):
    agnos = sorted(serie_horaria['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "DIAS", "GHImes", "GHIdiario"])
    for agno in agnos:
        for mes in range(1,13):
            nombre_energia = list(serie_horaria)[-1]
            dias = sorted(serie_horaria[(serie_horaria['AÑO'] == agno) &
                        (serie_horaria['MES'] == mes)]["DIA"].unique())
            ghi_mes = serie_horaria.loc[((serie_horaria["AÑO"] == agno)
                            & (serie_horaria["MES"] == mes)),
                                        nombre_energia].sum()/1000
            ghi_dia_prom=serie_horaria.loc[((serie_horaria["AÑO"] == agno)
                            & (serie_horaria["MES"] == mes)),
                                        nombre_energia].sum()/1000/dias[-1]
            ghi_dict = {"AÑO":agno, "MES":mes, "DIAS":dias[-1],
                        "GHImes":ghi_mes,"GHIdiario":ghi_dia_prom}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
    return ghi_df

# %%
def dfCyF(ciudad, fuente):
    base_dir = os.path.join( '.','data')
    output_dir = os.path.join( '.','output')
    serie_csv = os.path.join(base_dir,ciudad,fuente+'.csv')
    serie_pd = pd.read_csv(serie_csv, sep = ';',
                encoding='latin-1')
    a="df"+ciudad+"_"+fuente
    a=ghi(serie_pd)
    return a

# %%
dfCyF("Barranquilla","NREL")
# Out:
#         AÑO   MES  DIAS    GHImes  GHIdiario
# 0    2005.0   1.0  31.0  186.2635   6.008500
# 1    2005.0   2.0  28.0  184.4970   6.589179
# 2    2005.0   3.0  31.0  211.0165   6.806984
# 3    2005.0   4.0  30.0  186.1970   6.206567
# 4    2005.0   5.0  31.0  173.2945   5.590145
# 5    2005.0   6.0  30.0  172.2690   5.742300
# 6    2005.0   7.0  31.0  193.9895   6.257726
# 7    2005.0   8.0  31.0  187.0415   6.033597
# 8    2005.0   9.0  30.0  178.2525   5.941750
# 9    2005.0  10.0  31.0  155.0790   5.002548
# 10   2005.0  11.0  30.0  144.8120   4.827067
# 11   2005.0  12.0  31.0  179.4405   5.788403
# 12   2006.0   1.0  31.0  183.7330   5.926871
# 13   2006.0   2.0  28.0  184.6995   6.596411
# 14   2006.0   3.0  31.0  202.8685   6.544145
# 15   2006.0   4.0  30.0  192.6410   6.421367
# 16   2006.0   5.0  31.0  191.1960   6.167613
# 17   2006.0   6.0  30.0  175.1605   5.838683
# 18   2006.0   7.0  31.0  195.4300   6.304194
# 19   2006.0   8.0  31.0  192.9110   6.222935
# ...

# %%
GHI = dfCyF("Barranquilla","NREL")
datos_IDEAM = sorted(GHI["GHIdiario"])

# %%
pylab.xlabel("Datos")
pylab.ylabel("Energía/Energía Base IDEAM")
numdatos = range(len(datos_IDEAM))
pylab.plot(numdatos,datos_IDEAM/datos_IDEAM[0],'-k', label='IDEAM')
pylab.legend(loc='upper left')
pylab.savefig(os.path.join(output_dir,'valledupar_IDEAM.png'), dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f66925996d96> in <module>()
#       4 pylab.plot(numdatos,datos_IDEAM/datos_IDEAM[0],'-k', label='IDEAM')
#       5 pylab.legend(loc='upper left')
# ----> 6 pylab.savefig(os.path.join(output_dir,'valledupar_IDEAM.png'), dpi=600)
#
# NameError: name 'output_dir' is not defined

# %%
percentil = 0.01
enficc = ghi_diario_loc.quantile(q=percentil, 
                                 numeric_only=True)["GHIdiario"]
print('La ENFICC 99% es: ', enficc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2842460c0ba7> in <module>()
#       1 percentil = 0.01
# ----> 2 enficc = ghi_diario_loc.quantile(q=percentil,
#       3                                  numeric_only=True)["GHIdiario"]
#       4 print('La ENFICC 99% es: ', enficc)
#
# NameError: name 'ghi_diario_loc' is not defined

# %%
list(ghi_mensual_loc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ca46952906f8> in <module>()
# ----> 1 list(ghi_mensual_loc)
#
# NameError: name 'ghi_mensual_loc' is not defined
